# %% [markdown]
# # Task 2: Which molecule is it?
#
# You are given four anonymous XYZ files in `unknowns/` and a molecule library in `library`.

# %% [markdown]
# ## Task
#
# Find the library molecule that corresponds to each unknown molecule.
#
# Here, two structures are the same molecule if you can translate and rotate one structure onto the other.
#
# Your final answer should contain one match for each file:
#
# - `unknown_1.xyz`
# - `unknown_2.xyz`
# - `unknown_3.xyz`
# - `unknown_4.xyz`

# %% [markdown]
# ## Your solution

# %% [markdown]
# ## Final Answer
#
# - `unknown_1.xyz` ->
# - `unknown_2.xyz` ->
# - `unknown_3.xyz` ->
# - `unknown_4.xyz` ->
